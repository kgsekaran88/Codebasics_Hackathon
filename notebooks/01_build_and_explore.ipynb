# %% [markdown]
# # TN Assembly 2021 vs 2026 — Build & Explore
#
# Reproduces `data/processed/` tables and preview hero charts.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

# %run ../scripts/build_processed_data.py

# %%
import pandas as pd
from src.load_data import load_processed
from src.charts import fig_sankey, fig_tile_mosaic, fig_margin_beeswarm

comp = load_processed("ac_comparison.csv")
print("Flips:", comp["flip_norm"].sum())
print("Avg margin 2026:", comp["margin_pct_2026"].mean().round(2))
fig_sankey(load_processed("sankey_edges.csv")).show()
fig_tile_mosaic(comp).show()
fig_margin_beeswarm(comp).show()
